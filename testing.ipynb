# %%
import joblib
LE=joblib.load("LabelEncoder.pkl")
LOGR=joblib.load("LOGreg.pkl")

# %%
 ['Gender', 'Study_Hours', 'Attendance', 'Previous_Score',
       'Final_Score']
# Out:
# ['Gender', 'Study_Hours', 'Attendance', 'Previous_Score', 'Final_Score']

# %%
GENDER=input("Write your gender -- Male, Female --")
Gender=LE.fit_transform([GENDER])
print(Gender)
Study_Hours=int(input("write your study hour"))
Attendance=int(input("write your study hour"))
Previous_Score=int(input("write your study hour"))
Final_Score=int(input("write your study hour"))
print(Gender,Study_Hours,Attendance,Previous_Score,Final_Score)
# Out:
# [0]
# [0] 8 75 75 75

# %%
LOGR.predict([[0,Study_Hours, Attendance, Previous_Score, Final_Score]])
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
import numpy as np

x = np.array([0, Study_Hours, Attendance, Previous_Score, Final_Score])  # 1D array

# %%
pred = LOGR.predict(x.reshape(1, -1))
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
if pred[0] == 1:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass
